# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/tmp/results.csv')

# %%
data.describe()
# Out:
#              MDR        MTD       MTFA        ET
# count  57.000000  57.000000  57.000000  57.00000
# mean    0.370330   0.464767   0.806332   1.25086
# std     0.345582   0.292841   0.272519   0.47776
# min     0.000000   0.000000   0.000000   0.30081
# 25%     0.000000   0.286550   0.742700   1.02538
# 50%     0.250000   0.388020   0.943860   1.13876
# 75%     0.625000   0.665600   0.989920   1.50862
# max     1.000000   1.000000   1.000000   2.42401

# %%
for ds in 'toy log lor'.split():
    tmp_df = data[data['dataset'].str.contains(ds)]
    
    sns.factorplot(data=tmp_df, x='MDR', y='algorithm', col='dataset', kind="bar")
    
    sns.factorplot(data=tmp_df, x='MTD', y='MTFA', col='dataset', hue='algorithm')
    
plt.show()
